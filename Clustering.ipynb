# %% [markdown]
# Recuerda que para la enfermedad válvula aórtica bicúspide es relevante sólo AAo y AArch.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data 
data = pd.ExcelFile("PATIENT2.xlsx")
AAo = pd.read_excel(data,"AAo")
AArch = pd.read_excel(data,"AArch")

# Show dataframe
AAo
# Out:
#     Classification  Diameter  Eccentricity  Velocity  Forward Velocity  \
# 0                3  4.409020      40.30554  0.342057          0.260807
# 1                1  3.188276      59.72027  0.475692          0.298864
# 2                1  2.809120      17.55220  0.503216          0.482218
# 3                1  3.103340      23.64305  0.364040          0.306439
# 4                2  3.772210      30.83249  0.431897          0.324484
# ..             ...       ...           ...       ...               ...
# 69               2  4.840697      50.17573  0.373456          0.194321
# 70               2  4.447804      49.06510  0.430601          0.278444
# 71               1  3.782670      41.92589  0.370231          0.258961
# 72               2  4.839054      40.54989  0.239804          0.142059
# 73               2  3.908719      45.20829  0.276837          0.184107
#
#     Backward Velocity  Velocity Angle  Regurgitation Fraction       WSS  \
# 0            0.021773        41.52905                47.81968  0.499914
# 1            0.029619        53.50686                30.51788  0.990338
# 2            0.000033        13.89170                 6.32762  0.690250
# 3            0.010253        33.23474                30.79912  0.522163
# 4            0.051176        51.18690                30.71887  0.494690
# ..                ...             ...                     ...       ...
# 69           0.038413        63.97733                30.57477  0.479164
# 70           0.048523        57.05527                38.62353  0.530331
# 71           0.015651        44.16172                32.19650  0.498551
# 72           0.017705        55.46895                58.29099  0.283321
# 73           0.010953        48.85429                41.18114  0.451969
#
#        WSS A     WSS C       OSI  Vorticity  Axial Vorticity  \
# 0   0.418136  0.208428  0.197484   52.77399        11.684100
# 1   0.722975  0.560210  0.104026   95.77427        47.600550
# 2   0.651428  0.157048  0.133162   76.12720        12.581100
# 3   0.428749  0.212141  0.215152   67.84367        17.924250
# 4   0.430821  0.171874  0.166689   82.10398        10.839710
# ..       ...       ...       ...        ...              ...
# 69  0.306486  0.307230  0.173884   68.39531        17.289080
# 70  0.411389  0.269545  0.191458   82.67314        15.011190
# 71  0.365186  0.266087  0.193985   72.21935        19.080760
# 72  0.194512  0.162330  0.166070   44.68096         8.064042
# 73  0.334680  0.239254  0.122438   51.81093        17.634800
#
#     Axial Circulation  Helicity Density  Viscous Dissipation  Energy Loss  \
# 0            181.0080          7.115725             3.942029     0.255910
# 1            386.8463         12.254340             7.799821     0.365816
# 2             90.3981          9.743040             7.474800     0.481260
# 3            148.7738          7.425362             6.316028     0.402416
# 4            121.1615          9.271450             9.318917     0.609416
# ..                ...               ...                  ...          ...
# 69           344.3486          8.795052             6.844994     0.442775
# 70           269.5945         12.260000            11.155020     0.721605
# 71           235.8498          8.888168             7.997872     0.521516
# 72           159.1834          4.193274             3.469351     0.224418
# 73           195.6751          5.147518             3.763717     0.198953
#
#     Kinetic Energy    Age
# 0         1.363937  68.00
# 1         2.110996  28.23
# 2         2.820980  34.35
# 3         1.674334  28.41
# 4         2.402694  34.00
# ..             ...    ...
# 69        1.637745  65.02
# 70        2.263447  71.00
# 71        1.680506  59.00
# 72        0.744026  68.00
# 73        0.866577  48.00
#
# [74 rows x 20 columns]

# %%
AArch
# Out:
#     Classification  Diameter  Eccentricity  Velocity  Forward Velocity  \
# 0                3   2.98814       22.2449  0.279806          0.241883
# 1                1   1.72030       11.3750  0.538280          0.519547
# 2                1   2.33183       12.7243  0.533569          0.516071
# 3                1   2.36587       17.8319  0.314034          0.293230
# 4                2   2.26493       21.8988  0.427359          0.384227
# ..             ...       ...           ...       ...               ...
# 69               2   3.18445       22.7930  0.289387          0.246234
# 70               2   3.00990       20.5743  0.362242          0.333093
# 71               1   2.53574       18.4228  0.289856          0.259441
# 72               2   2.76748       22.8983  0.210183          0.170993
# 73               2   2.36858       24.3914  0.224529          0.192008
#
#     Backward Velocity  Velocity Angle  Regurgitation Fraction       WSS  \
# 0            0.009648        25.30380                61.38250  0.493316
# 1            0.001010         9.67785                 3.38574  1.233990
# 2            0.000000        11.01920                 6.15209  0.927163
# 3            0.000345        16.31800                10.96060  0.519229
# 4            0.002630        19.65230                26.73980  0.827168
# ..                ...             ...                     ...       ...
# 69           0.003218        26.17860                22.26890  0.450936
# 70           0.002250        19.53480                24.71380  0.598737
# 71           0.002896        23.02020                22.84230  0.528730
# 72           0.003628        30.44660                43.72880  0.378351
# 73           0.002143        26.14410                25.15720  0.457735
#
#        WSS A     WSS C       OSI  Vorticity  Axial Vorticity  \
# 0   0.457388  0.138190  0.265571    41.1878        -0.065862
# 1   1.204280  0.165346  0.060475    63.0307        21.720100
# 2   0.905070  0.140563  0.107797    64.8266        10.353400
# 3   0.484379  0.132226  0.189934    49.6177        10.329400
# 4   0.767196  0.194223  0.222490    66.9590        10.853800
# ..       ...       ...       ...        ...              ...
# 69  0.399388  0.146053  0.156673    43.4084         8.173860
# 70  0.560567  0.151476  0.199693    48.5816         7.052540
# 71  0.494995  0.123372  0.214253    47.9067         2.684130
# 72  0.340116  0.110178  0.230571    41.2404         2.487720
# 73  0.423762  0.109441  0.141387    36.4950         7.706810
#
#     Axial Circulation  Helicity Density  Viscous Dissipation  Energy Loss  \
# 0           -0.151764           3.45716              2.44047     0.157601
# 1           56.246500           9.63140              6.11533     0.283544
# 2           53.182900           9.04476              5.35477     0.351310
# 3           50.778900           5.78472              5.14049     0.326946
# 4           70.728400           9.72526              8.58193     0.555900
# ..                ...               ...                  ...          ...
# 69          79.960200           4.61056              2.99767     0.195166
# 70          55.629900           5.87501              4.11173     0.266144
# 71          14.665400           4.56453              4.72428     0.306099
# 72          15.299400           2.83553              2.73271     0.177812
# 73          24.100600           3.07101              2.80292     0.150350
#
#     Kinetic Energy    Age
# 0         0.837510  68.00
# 1         2.908060  28.23
# 2         2.996280  34.35
# 3         1.236830  28.41
# 4         2.185700  34.00
# ..             ...    ...
# 69        0.942478  65.02
# 70        1.486810  71.00
# 71        1.059250  59.00
# 72        0.561399  68.00
# 73        0.616643  48.00
#
# [74 rows x 20 columns]

# %%
AAo = AAo.drop(["Diameter"], axis=1)
AAo = AAo.drop(["Kinetic Energy"], axis=1)
AAo
# Out:
#     Classification  Eccentricity  Velocity  Forward Velocity  \
# 0                3      40.30554  0.342057          0.260807
# 1                1      59.72027  0.475692          0.298864
# 2                1      17.55220  0.503216          0.482218
# 3                1      23.64305  0.364040          0.306439
# 4                2      30.83249  0.431897          0.324484
# ..             ...           ...       ...               ...
# 69               2      50.17573  0.373456          0.194321
# 70               2      49.06510  0.430601          0.278444
# 71               1      41.92589  0.370231          0.258961
# 72               2      40.54989  0.239804          0.142059
# 73               2      45.20829  0.276837          0.184107
#
#     Backward Velocity  Velocity Angle  Regurgitation Fraction       WSS  \
# 0            0.021773        41.52905                47.81968  0.499914
# 1            0.029619        53.50686                30.51788  0.990338
# 2            0.000033        13.89170                 6.32762  0.690250
# 3            0.010253        33.23474                30.79912  0.522163
# 4            0.051176        51.18690                30.71887  0.494690
# ..                ...             ...                     ...       ...
# 69           0.038413        63.97733                30.57477  0.479164
# 70           0.048523        57.05527                38.62353  0.530331
# 71           0.015651        44.16172                32.19650  0.498551
# 72           0.017705        55.46895                58.29099  0.283321
# 73           0.010953        48.85429                41.18114  0.451969
#
#        WSS A     WSS C       OSI  Vorticity  Axial Vorticity  \
# 0   0.418136  0.208428  0.197484   52.77399        11.684100
# 1   0.722975  0.560210  0.104026   95.77427        47.600550
# 2   0.651428  0.157048  0.133162   76.12720        12.581100
# 3   0.428749  0.212141  0.215152   67.84367        17.924250
# 4   0.430821  0.171874  0.166689   82.10398        10.839710
# ..       ...       ...       ...        ...              ...
# 69  0.306486  0.307230  0.173884   68.39531        17.289080
# 70  0.411389  0.269545  0.191458   82.67314        15.011190
# 71  0.365186  0.266087  0.193985   72.21935        19.080760
# 72  0.194512  0.162330  0.166070   44.68096         8.064042
# 73  0.334680  0.239254  0.122438   51.81093        17.634800
#
#     Axial Circulation  Helicity Density  Viscous Dissipation  Energy Loss  \
# 0            181.0080          7.115725             3.942029     0.255910
# 1            386.8463         12.254340             7.799821     0.365816
# 2             90.3981          9.743040             7.474800     0.481260
# 3            148.7738          7.425362             6.316028     0.402416
# 4            121.1615          9.271450             9.318917     0.609416
# ..                ...               ...                  ...          ...
# 69           344.3486          8.795052             6.844994     0.442775
# 70           269.5945         12.260000            11.155020     0.721605
# 71           235.8498          8.888168             7.997872     0.521516
# 72           159.1834          4.193274             3.469351     0.224418
# 73           195.6751          5.147518             3.763717     0.198953
#
#       Age
# 0   68.00
# 1   28.23
# 2   34.35
# 3   28.41
# 4   34.00
# ..    ...
# 69  65.02
# 70  71.00
# 71  59.00
# 72  68.00
# 73  48.00
#
# [74 rows x 18 columns]

# %%
AArch = AArch.drop(["Diameter"], axis=1)
AArch = AArch.drop(["Kinetic Energy"], axis=1)
AArch
# Out:
#     Classification  Eccentricity  Velocity  Forward Velocity  \
# 0                3       22.2449  0.279806          0.241883
# 1                1       11.3750  0.538280          0.519547
# 2                1       12.7243  0.533569          0.516071
# 3                1       17.8319  0.314034          0.293230
# 4                2       21.8988  0.427359          0.384227
# ..             ...           ...       ...               ...
# 69               2       22.7930  0.289387          0.246234
# 70               2       20.5743  0.362242          0.333093
# 71               1       18.4228  0.289856          0.259441
# 72               2       22.8983  0.210183          0.170993
# 73               2       24.3914  0.224529          0.192008
#
#     Backward Velocity  Velocity Angle  Regurgitation Fraction       WSS  \
# 0            0.009648        25.30380                61.38250  0.493316
# 1            0.001010         9.67785                 3.38574  1.233990
# 2            0.000000        11.01920                 6.15209  0.927163
# 3            0.000345        16.31800                10.96060  0.519229
# 4            0.002630        19.65230                26.73980  0.827168
# ..                ...             ...                     ...       ...
# 69           0.003218        26.17860                22.26890  0.450936
# 70           0.002250        19.53480                24.71380  0.598737
# 71           0.002896        23.02020                22.84230  0.528730
# 72           0.003628        30.44660                43.72880  0.378351
# 73           0.002143        26.14410                25.15720  0.457735
#
#        WSS A     WSS C       OSI  Vorticity  Axial Vorticity  \
# 0   0.457388  0.138190  0.265571    41.1878        -0.065862
# 1   1.204280  0.165346  0.060475    63.0307        21.720100
# 2   0.905070  0.140563  0.107797    64.8266        10.353400
# 3   0.484379  0.132226  0.189934    49.6177        10.329400
# 4   0.767196  0.194223  0.222490    66.9590        10.853800
# ..       ...       ...       ...        ...              ...
# 69  0.399388  0.146053  0.156673    43.4084         8.173860
# 70  0.560567  0.151476  0.199693    48.5816         7.052540
# 71  0.494995  0.123372  0.214253    47.9067         2.684130
# 72  0.340116  0.110178  0.230571    41.2404         2.487720
# 73  0.423762  0.109441  0.141387    36.4950         7.706810
#
#     Axial Circulation  Helicity Density  Viscous Dissipation  Energy Loss  \
# 0           -0.151764           3.45716              2.44047     0.157601
# 1           56.246500           9.63140              6.11533     0.283544
# 2           53.182900           9.04476              5.35477     0.351310
# 3           50.778900           5.78472              5.14049     0.326946
# 4           70.728400           9.72526              8.58193     0.555900
# ..                ...               ...                  ...          ...
# 69          79.960200           4.61056              2.99767     0.195166
# 70          55.629900           5.87501              4.11173     0.266144
# 71          14.665400           4.56453              4.72428     0.306099
# 72          15.299400           2.83553              2.73271     0.177812
# 73          24.100600           3.07101              2.80292     0.150350
#
#       Age
# 0   68.00
# 1   28.23
# 2   34.35
# 3   28.41
# 4   34.00
# ..    ...
# 69  65.02
# 70  71.00
# 71  59.00
# 72  68.00
# 73  48.00
#
# [74 rows x 18 columns]

# %%
plt.figure(figsize=(15,10))
plt.title("AAo")
correlations = AAo.corr()
sns.heatmap(round(correlations,2), cmap='RdBu', annot=True, 
            annot_kws={"size": 7}, vmin=-1, vmax=1);

# %%
plt.figure(figsize=(15,10))
plt.title("AArch")
correlations = AArch.corr()
sns.heatmap(round(correlations,2), cmap='RdBu', annot=True, 
            annot_kws={"size": 7}, vmin=-1, vmax=1);

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform

plt.figure(figsize=(12,5))
plt.title("AAo")
dissimilarity = 1 - abs(correlations)
Z = linkage(squareform(dissimilarity), 'complete')

dendrogram(Z, labels=AAo.columns, orientation='top', 
           leaf_rotation=90);

# %%
plt.figure(figsize=(12,5))
plt.title("AArch")
dissimilarity = 1 - abs(correlations)
Z2 = linkage(squareform(dissimilarity), 'complete')

dendrogram(Z2, labels=AArch.columns, orientation='top', 
           leaf_rotation=90);

# %%
# Clusterize the data (AAo)
threshold = 0.8
labels = fcluster(Z, threshold, criterion='distance')

# Show the cluster
labels
# Out:
# array([5, 5, 1, 2, 5, 2, 5, 2, 2, 4, 4, 1, 4, 4, 1, 1, 1, 3], dtype=int32)

# %%
# Clusterize the data (AArch)
threshold = 0.8
labels2 = fcluster(Z2, threshold, criterion='distance')

# Show the cluster
labels
# Out:
# array([5, 5, 1, 2, 5, 2, 5, 2, 2, 4, 4, 1, 4, 4, 1, 1, 1, 3], dtype=int32)

# %%
import numpy as np

# Keep the indices to sort labels
labels_order = np.argsort(labels)

# Build a new dataframe with the sorted columns
for idx, i in enumerate(AAo.columns[labels_order]):
    if idx == 0:
        clustered = pd.DataFrame(AAo[i])
    else:
        df_to_append = pd.DataFrame(AAo[i])
        clustered = pd.concat([clustered, df_to_append], axis=1)

# %%
# Keep the indices to sort labels
labels_order = np.argsort(labels2)

# Build a new dataframe with the sorted columns
for idx, i in enumerate(AArch.columns[labels_order]):
    if idx == 0:
        clustered2 = pd.DataFrame(AArch[i])
    else:
        df_to_append = pd.DataFrame(AArch[i])
        clustered2 = pd.concat([clustered2, df_to_append], axis=1)

# %%
plt.figure(figsize=(15,10))
plt.title("AAo")
correlations = clustered.corr()
sns.heatmap(round(correlations,2), cmap='RdBu', annot=True, 
            annot_kws={"size": 7}, vmin=-1, vmax=1);

# %%
plt.figure(figsize=(15,10))
plt.title("AArch")
correlations2 = clustered2.corr()
sns.heatmap(round(correlations2,2), cmap='RdBu', annot=True, 
            annot_kws={"size": 7}, vmin=-1, vmax=1);

# %%
sns.clustermap(correlations, method="complete", cmap='RdBu', annot=True, 
               annot_kws={"size": 7}, vmin=-1, vmax=1, figsize=(15,12));

# %%
sns.clustermap(correlations2, method="complete", cmap='RdBu', annot=True, 
               annot_kws={"size": 7}, vmin=-1, vmax=1, figsize=(15,12));
